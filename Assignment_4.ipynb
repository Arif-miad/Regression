# %%
from sklearn.model_selection import train_test_split

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('/content/lr.csv.csv')

# %%
df
# Out:
#          Height      Weight
# 0     73.847017  241.893563
# 1     68.781904  162.310473
# 2     74.110105  212.740856
# 3     71.730978  220.042470
# 4     69.881796  206.349801
# ...         ...         ...
# 3496  69.296830  185.649086
# 3497  70.542201  210.198845
# 3498  73.912549  202.429960
# 3499  67.396021  144.277671
# 3500  72.738970  187.222909
#
# [3501 rows x 2 columns]

# %%
df.head()
# Out:
#       Height      Weight
# 0  73.847017  241.893563
# 1  68.781904  162.310473
# 2  74.110105  212.740856
# 3  71.730978  220.042470
# 4  69.881796  206.349801

# %%
df.isnull().sum()
# Out:
# Height    0
# Weight    0
# dtype: int64

# %%
df.shape
# Out:
# (3501, 2)

# %%
df.info
# Out:
# <bound method DataFrame.info of          Height      Weight
# 0     73.847017  241.893563
# 1     68.781904  162.310473
# 2     74.110105  212.740856
# 3     71.730978  220.042470
# 4     69.881796  206.349801
# ...         ...         ...
# 3496  69.296830  185.649086
# 3497  70.542201  210.198845
# 3498  73.912549  202.429960
# 3499  67.396021  144.277671
# 3500  72.738970  187.222909
#
# [3501 rows x 2 columns]>

# %%
plt.scatter(df['Height'], df['Weight'])

# %%
plt.scatter(df.Height, df.Weight, color='green', marker='+')

# %%
plt.scatter(df.Height, df.Weight, color='green', marker='+')
plt.xlabel("Heigh", color='black')
plt.ylabel("Weight", color='red')
plt.title('shop plot', color='skyblue')
# Out:
# Text(0.5, 1.0, 'shop plot')

# %%
df.Height.mean()
# Out:
# 69.02441087268781

# %%
df.Weight.mean()
# Out:
# 186.891257979463

# %%
df.head()
# Out:
#       Height      Weight
# 0  73.847017  241.893563
# 1  68.781904  162.310473
# 2  74.110105  212.740856
# 3  71.730978  220.042470
# 4  69.881796  206.349801

# %%
x = df[['Height']]

# %%
y = df[['Weight']]

# %%
x.head()
# Out:
#       Height
# 0  73.847017
# 1  68.781904
# 2  74.110105
# 3  71.730978
# 4  69.881796

# %%
y.head()
# Out:
#        Weight
# 0  241.893563
# 1  162.310473
# 2  212.740856
# 3  220.042470
# 4  206.349801

# %%
df.shape
# Out:
# (3501, 2)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=.30)

# %%
xtrain.head()
# Out:
#          Height
# 2979  67.144530
# 2540  74.706964
# 3160  69.639312
# 1999  65.078524
# 2832  67.500067

# %%
xtest.head()
# Out:
#          Height
# 2633  68.374531
# 2503  71.768822
# 2687  64.838194
# 1199  66.209617
# 1407  71.250136

# %%
xtrain.shape
# Out:
# (2450, 1)

# %%
xtest.shape
# Out:
# (1051, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
reg.predict([[2000]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([[11623.77869968]])

# %%
xtrain.head()
# Out:
#          Height
# 2979  67.144530
# 2540  74.706964
# 3160  69.639312
# 1999  65.078524
# 2832  67.500067

# %%
ytrain.head(5)
# Out:
#           Weight
# 2979  185.787865
# 2540  215.225509
# 3160  174.157633
# 1999  174.743510
# 2832  175.879804

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
reg.predict([[4000]])
# Out:
# array([[23469.51379264]])

# %%
ytest.head()
# Out:
#           Weight
# 2633  190.920243
# 2503  182.072242
# 2687  142.725871
# 1199  182.946419
# 1407  191.067620

# %%
ypred = reg.predict(xtest)

# %%
ypred
# Out:
# array([[183.01689673],
#        [203.12083611],
#        [162.07163942],
#        ...,
#        [189.34186947],
#        [171.71908925],
#        [143.33887183]])

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(ytest, ypred)

# %%
mse
# Out:
# 103.44061591080556

# %%
from sklearn.metrics import mean_absolute_error

# %%
mae = mean_absolute_error(ytest, ypred)

# %%
mae
# Out:
# 8.128030840429714

# %%
m = reg.coef_

# %%
m
# Out:
# array([[5.92286755]])

# %%
c = reg.intercept_

# %%
c
# Out:
# array([-221.95639329])

# %%
result = m*45600+c

# %%
result
# Out:
# array([[269860.80372635]])

# %%
plt.plot(xtest, reg.predict(xtest))

# %%
pred = reg.predict(xtest)
plt.plot(xtest, pred)

# %%
plt.plot(df.Height, reg.predict(df[['Height']]))

# %%
plt.scatter(df.Height, df.Weight, color='#C70039', marker='*')
plt.xlabel('Height side of product')
plt.ylabel('Weight side of product')
plt.title('Binary plot of the supper shop')
plt.plot(df.Height, reg.predict(df[['Height']]), color='DodgerBlue')

# %%
xtrain.head()
# Out:
#          Height
# 2979  67.144530
# 2540  74.706964
# 3160  69.639312
# 1999  65.078524
# 2832  67.500067

# %%
xtrain.to_csv('x2.csv')

# %%
x2 = pd.read_csv('x2.csv')

# %%
x2.drop('Unnamed: 0', axis=1, inplace=True)

# %%
x2.head()
# Out:
#       Height
# 0  67.144530
# 1  74.706964
# 2  69.639312
# 3  65.078524
# 4  67.500067

# %%
reg.predict(x2)
# Out:
# array([[175.7317639 ],
#        [220.52305988],
#        [190.50802718],
#        ...,
#        [189.45088067],
#        [167.41268947],
#        [173.0149163 ]])

# %%
reg.score(xtest, ytest)
# Out:
# 0.7471740218059311

# %%
reg.score(xtrain, ytrain)
# Out:
# 0.725641224031233

# %%
pred = reg.predict(xtest)
plt.plot(xtest, pred)

# %%
pred = reg.predict(xtest)
plt.plot(np.squeeze(xtest), pred )
